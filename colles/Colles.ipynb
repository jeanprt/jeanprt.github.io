# %% [markdown]
# # Marche à suivre :
#
#
# 1. Vous devez exécuter les cellules de code les unes après les autres. Pensez bien à entrer le groupe de colle choisi au bas de la cellule quand celle-ci s'exécute.
# Les cellues s'executent avec le petit bouton play en haut à gauche de chaque.
# 2. Vous trouverez un fichier par matière dans l'explorateur de fichier à droit de l'écran. Téléchargez les fichiers.
# 3. Après avoir téléchargé les fichiers, vous pouvez les importer dans votre calendrier google, outlook, apple, etc, en utilisant la fonction : importer un calendrier ical.
#
# ##### Version mise à jour : "Kholloscope V9" le 30/09/2024

# %%
# %pip install pandas icalendar
# Out:
# Requirement already satisfied: pandas in /usr/local/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: icalendar in /usr/local/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (6.1.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/Cellar/jupyterlab/4.3.1_1/libexec/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Colles d'anglais
import pandas as pd
from icalendar import Calendar, Event
from datetime import datetime
import io

data = '''
,horaire,salle,2/9/2024,9/9/2024,16/9/2024,23/9/2024,30/9/2024,7/10/2024,14/10/2024,,4/11/2024,11/11/2024,18/11/2024,25/11/2024,2/12/2024,9/12/2024,16/12/2024,,6/1/2025,13/1/2025,20/1/2025,27/1/2025,3/2/2025,10/2/2025,17/2/2025
,,,,,,,,,,,,,,,,,,,,,,,,,
Anglais,,,,,,,,,,,,,,,,,,,,,,,,,
Mme Tschudi,Lu 12-13,E02 E04,,,,1,2,3,4,,5,6,7,8,9,14,11,,12,13,14,1,2,3,2
Mme Mc Grath,Lu 12-13,E20,,,,3,4,13,6,,7,8,9,10,11,12,7,,14,7,16,15,6,1,4
Mme Mc Grath,Lu 13-14,E20,,,,5,12,1,14,,15,16,11,2,13,10,5,,8,1,2,3,4,5,6
Mme Rébillon,Lu 13-14,E08 E10,,,,7,8,9,8,,9,4,3,14,15,16,13,,2,15,4,5,16,11,8
M. Coquilhat,Lu 13-14,K08 K09,,,,9,10,5,12,,13,14,15,16,1,2,3,,16,11,6,7,8,9,10
Mme Heikka,Lu 18-19,E01 E05,,,,15,14,11,16,,11,10,1,12,3,4,15,,6,3,10,9,10,15,12
Mme Otéro,Ma 17-18,B21 B22,,,,13,6,15,10,,1,12,13,6,5,8,1,,4,9,8,13,12,7,14
Mme Otéro,Ma 18-19,B21 B22,,,,11,16,7,2,,3,2,5,4,7,6,9,,10,5,12,11,14,13,16
'''

group = float(input('Entrez le groupe de colle souhaité ici '))

df = pd.read_csv(io.StringIO(data))

# Créer un objet Calendrier
cal = Calendar()

# Définir la matière
matiere = df.iloc[1,0]

# Parcourir les lignes du DataFrame à partir de la ligne 3 (index 2)
for index, ligne in df.iloc[2:].iterrows():
  # Extraire les informations
  professeur = ligne.iloc[0]
  info_date_heure = ligne.iloc[1]
  salle = ligne.iloc[2]

  # Parcourir les colonnes de dates à partir de la 4ème colonne (index 3)
  for i in range(3, len(df.columns)):
    semaine = df.columns[i]
    valeur = ligne.iloc[i]

    # Vérifier si la valeur est 14
    if valeur == group:
      # Vérifier si la cellule contient le format attendu et n'est pas vide
      if isinstance(info_date_heure, str) and " " in info_date_heure:
        jour, horaire = info_date_heure.split(' ')
        heure_debut, heure_fin = horaire.split('-')

        # Calculer la date complète de l'événement
        if jour == 'Lu':
          jour_semaine = 0
        elif jour == 'Ma':
          jour_semaine = 1
        elif jour == 'Me':
          jour_semaine = 2
        elif jour == 'Je':
          jour_semaine = 3
        elif jour == 'Ve':
          jour_semaine = 4

        date_event = datetime.strptime(semaine, '%d/%m/%Y') + pd.DateOffset(days=jour_semaine)

        # Définir l'heure de début et de fin de l'événement
        heure_debut = int(heure_debut)
        heure_fin = int(heure_fin)

        # Créer un objet Événement
        event = Event()
        event.add('summary', f"Colle {matiere} {professeur}")
        event.add('location', salle)
        event.add('dtstart', datetime(date_event.year, date_event.month, date_event.day, heure_debut, 0))
        event.add('dtend', datetime(date_event.year, date_event.month, date_event.day, heure_fin, 0))
        cal.add_component(event)

# Enregistrer le calendrier dans un fichier .ics
with open(f"Colles de {matiere} groupe {round(group)}.ics", 'wb') as f:
    f.write(cal.to_ical())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 21
#       5 import io
#       7 data = '''
#       8 ,horaire,salle,2/9/2024,9/9/2024,16/9/2024,23/9/2024,30/9/2024,7/10/2024,14/10/2024,,4/11/2024,11/11/2024,18/11/2024,25/11/2024,2/12/2024,9/12/2024,16/12/2024,,6/1/2025,13/1/2025,20/1/2025,27/1/2025,3/2/2025,10/2/2025,17/2/2025
#       9 ,,,,,,,,,,,,,,,,,,,,,,,,,
#    (...)
#      18 Mme Otéro,Ma 18-19,B21 B22,,,,11,16,7,2,,3,2,5,4,7,6,9,,10,5,12,11,14,13,16
#      19 '''
# ---> 21 group = float(input('Entrez le groupe de colle souhaité ici '))
#      23 df = pd.read_csv(io.StringIO(data))
#      25 # Créer un objet Calendrier
#
# ValueError: could not convert string to float: ''

# %%
# Colles de Maths
import pandas as pd
from icalendar import Calendar, Event
from datetime import datetime
import io

data = '''
,horaire,salle,2/9/2024,9/9/2024,16/9/2024,23/9/2024,30/9/2024,7/10/2024,14/10/2024,,4/11/2024,11/11/2024,18/11/2024,25/11/2024,2/12/2024,9/12/2024,16/12/2024,,6/1/2025,13/1/2025,20/1/2025,27/1/2025,3/2/2025,10/2/2025,17/2/2025
,,,,,,,,,,,,,,,,,,,,,,,,,
Maths,,,,,,,,,,,,,,,,,,,,,,,,,
M. Sautonie,Lu 12-13,E01,,,,,16,7,2,,11,10,5,6,7,4,9,,10,3,12,9,14,15,16
M. Falconnet,Lu 13-14,F106,,,,,14,11,16,,1,2,1,12,5,6,15,,6,5,10,11,12,13,14
Mme Plà,Ma 12-13,E01,,,,,8,1,14,,9,16,7,2,3,12,5,,14,7,8,13,4,3,12
Mme Plà,Ma 13-14,E01,,,,,10,15,12,,5,14,15,10,1,8,3,,4,9,6,1,8,9,10
M. Magniez,Ma 13-14,F103,,,,,6,5,10,,3,12,13,8,15,16,1,,2,11,4,5,16,1,2
M. Sageaux,Ma 17-18,F205,,,,,4,13,8,,7,4,11,4,13,10,7,,16,13,2,15,10,5,4
M. Raymond,Ma 18-19,E04,,,,,12,9,6,,15,8,9,16,11,14,13,,12,15,16,7,2,11,6
Mme Deville,Je 17-18,B21,,,,,2,3,4,,13,6,3,14,9,2,11,,8,1,14,3,6,7,8
'''

group = float(input('Entrez le groupe de colle souhaité ici '))

df = pd.read_csv(io.StringIO(data))

# Créer un objet Calendrier
cal = Calendar()

# Définir la matière
matiere = df.iloc[1,0]

# Parcourir les lignes du DataFrame à partir de la ligne 3 (index 2)
for index, ligne in df.iloc[2:].iterrows():
  # Extraire les informations
  professeur = ligne.iloc[0]
  info_date_heure = ligne.iloc[1]
  salle = ligne.iloc[2]

  # Parcourir les colonnes de dates à partir de la 4ème colonne (index 3)
  for i in range(3, len(df.columns)):
    semaine = df.columns[i]
    valeur = ligne.iloc[i]

    # Vérifier si la valeur est 14
    if valeur == group:
      # Vérifier si la cellule contient le format attendu et n'est pas vide
      if isinstance(info_date_heure, str) and " " in info_date_heure:
        jour, horaire = info_date_heure.split(' ')
        heure_debut, heure_fin = horaire.split('-')

        # Calculer la date complète de l'événement
        if jour == 'Lu':
          jour_semaine = 0
        elif jour == 'Ma':
          jour_semaine = 1
        elif jour == 'Me':
          jour_semaine = 2
        elif jour == 'Je':
          jour_semaine = 3
        elif jour == 'Ve':
          jour_semaine = 4

        date_event = datetime.strptime(semaine, '%d/%m/%Y') + pd.DateOffset(days=jour_semaine)

        # Définir l'heure de début et de fin de l'événement
        heure_debut = int(heure_debut)
        heure_fin = int(heure_fin)

        # Créer un objet Événement
        event = Event()
        event.add('summary', f"Colle {matiere} {professeur}")
        event.add('location', salle)
        event.add('dtstart', datetime(date_event.year, date_event.month, date_event.day, heure_debut, 0))
        event.add('dtend', datetime(date_event.year, date_event.month, date_event.day, heure_fin, 0))
        cal.add_component(event)

# Enregistrer le calendrier dans un fichier .ics
with open(f"Colles de {matiere} groupe {round(group)}.ics", 'wb') as f:
    f.write(cal.to_ical())
# Out:
# Entrez le groupe de colle souhaitez ici 3

# %%
# Colles de SI
import pandas as pd
from icalendar import Calendar, Event
from datetime import datetime
import io

data = '''
,horaire,salle,2/9/2024,9/9/2024,16/9/2024,23/9/2024,30/9/2024,7/10/2024,14/10/2024,,4/11/2024,11/11/2024,18/11/2024,25/11/2024,2/12/2024,9/12/2024,16/12/2024,,6/1/2025,13/1/2025,20/1/2025,27/1/2025,3/2/2025,10/2/2025,17/2/2025
,,,,,,,,,,,,,,,,,,,,,,,,,
SI,,,,,,,,,,,,,,,,,,,,,,,,,
Mme Pradier,Lu 12-13,B21,,,,2,11,4,3,,2,5,8,1,10,9,12,,11,8,13,16,15,2,11
M. Lisle,Lu 12-13,Labo PT,,,,4,3,6,5,,8,7,10,15,8,11,6,,13,16,15,8,1,4,3
Mme Pradier,Lu 13-14,B21,,,,6,5,2,7,,14,9,12,11,4,13,16,,15,2,1,12,3,6,5
M. Boyer,Lu 13-14,Labo PT,,,,8,7,10,9,,12,11,4,13,16,7,2,,1,6,9,6,5,8,7
M. Lisle,Ma 12-13,Labo PT,,,,16,9,12,11,,10,3,16,9,2,15,10,,3,14,5,4,7,10,15
M. Deluche,Ma 18-19,Labo PT,,,,12,15,14,13,,16,15,6,7,14,3,14,,5,4,7,2,13,16,1
M. Vallenet,Je 17-18,Labo PT,,,,14,13,16,15,,6,1,14,3,6,5,8,,7,12,11,14,11,14,13
M. Deluche,Ve 13-14,Labo PT,,,,10,1,8,1,,4,13,2,5,12,1,4,,9,10,3,10,9,12,9
'''

group = float(input('Entrez le groupe de colle souhaité ici '))

df = pd.read_csv(io.StringIO(data))

# Créer un objet Calendrier
cal = Calendar()

# Définir la matière
matiere = df.iloc[1,0]

# Parcourir les lignes du DataFrame à partir de la ligne 3 (index 2)
for index, ligne in df.iloc[2:].iterrows():
  # Extraire les informations
  professeur = ligne.iloc[0]
  info_date_heure = ligne.iloc[1]
  salle = ligne.iloc[2]

  # Parcourir les colonnes de dates à partir de la 4ème colonne (index 3)
  for i in range(3, len(df.columns)):
    semaine = df.columns[i]
    valeur = ligne.iloc[i]

    # Vérifier si la valeur est 14
    if valeur == group:
      # Vérifier si la cellule contient le format attendu et n'est pas vide
      if isinstance(info_date_heure, str) and " " in info_date_heure:
        jour, horaire = info_date_heure.split(' ')
        heure_debut, heure_fin = horaire.split('-')

        # Calculer la date complète de l'événement
        if jour == 'Lu':
          jour_semaine = 0
        elif jour == 'Ma':
          jour_semaine = 1
        elif jour == 'Me':
          jour_semaine = 2
        elif jour == 'Je':
          jour_semaine = 3
        elif jour == 'Ve':
          jour_semaine = 4

        date_event = datetime.strptime(semaine, '%d/%m/%Y') + pd.DateOffset(days=jour_semaine)

        # Définir l'heure de début et de fin de l'événement
        heure_debut = int(heure_debut)
        heure_fin = int(heure_fin)

        # Créer un objet Événement
        event = Event()
        event.add('summary', f"Colle {matiere} {professeur}")
        event.add('location', salle)
        event.add('dtstart', datetime(date_event.year, date_event.month, date_event.day, heure_debut, 0))
        event.add('dtend', datetime(date_event.year, date_event.month, date_event.day, heure_fin, 0))
        cal.add_component(event)

# Enregistrer le calendrier dans un fichier .ics
with open(f"Colles de {matiere} groupe {round(group)}.ics", 'wb') as f:
    f.write(cal.to_ical())
# Out:
# Entrez le groupe de colle souhaitez ici 3

# %%
# Colles de Physique
import pandas as pd
from icalendar import Calendar, Event
from datetime import datetime
import io

data = '''
,horaire,salle,2/9/2024,9/9/2024,16/9/2024,23/9/2024,30/9/2024,7/10/2024,14/10/2024,,4/11/2024,11/11/2024,18/11/2024,25/11/2024,2/12/2024,9/12/2024,16/12/2024,,6/1/2025,13/1/2025,20/1/2025,27/1/2025,3/2/2025,10/2/2025,17/2/2025
,,,,,,,,,,,,,,,,,,,,,,,,,
Physique,,,,,,,,,,,,,,,,,,,,,,,,,
Mme Lefort,Lu 12-13,H105,,,,,15,8,1,,10,3,16,9,2,1,10,,9,4,11,14,13,16,15
M. Raimi,Lu 12-13,H108,,,,,13,16,15,,6,1,14,3,6,5,8,,7,10,3,2,11,14,13
M. Qadri,Lu 12-13,B23,,,,,9,14,13,,16,15,2,7,14,15,14,,3,14,7,10,9,12,1
M. Scotto,Ma 17-18,H111,,,,,1,6,11,,4,13,10,5,12,7,4,,5,12,5,16,7,6,5
Mme Lines,Me 17-18,H105,,,,,11,4,9,,8,11,4,15,4,11,6,,15,6,9,4,15,8,9
M. Trollet,Me 18-19,H105,,,,,7,2,7,,14,5,12,11,16,13,16,,1,16,15,6,5,10,3
M Fayolle,Ve 12-13,E102,,,,,3,12,5,,12,7,6,13,8,3,2,,13,2,1,8,1,4,7
M Fanjeaux,Ve 12-13,H113,,,,,5,10,3,,2,9,8,1,10,9,12,,11,8,13,12,3,2,11
'''

group = float(input('Entrez le groupe de colle souhaité ici '))

df = pd.read_csv(io.StringIO(data))

# Créer un objet Calendrier
cal = Calendar()

# Définir la matière
matiere = df.iloc[1,0]

# Parcourir les lignes du DataFrame à partir de la ligne 3 (index 2)
for index, ligne in df.iloc[2:].iterrows():
  # Extraire les informations
  professeur = ligne.iloc[0]
  info_date_heure = ligne.iloc[1]
  salle = ligne.iloc[2]

  # Parcourir les colonnes de dates à partir de la 4ème colonne (index 3)
  for i in range(3, len(df.columns)):
    semaine = df.columns[i]
    valeur = ligne.iloc[i]

    # Vérifier si la valeur est 14
    if valeur == group:
      # Vérifier si la cellule contient le format attendu et n'est pas vide
      if isinstance(info_date_heure, str) and " " in info_date_heure:
        jour, horaire = info_date_heure.split(' ')
        heure_debut, heure_fin = horaire.split('-')

        # Calculer la date complète de l'événement
        if jour == 'Lu':
          jour_semaine = 0
        elif jour == 'Ma':
          jour_semaine = 1
        elif jour == 'Me':
          jour_semaine = 2
        elif jour == 'Je':
          jour_semaine = 3
        elif jour == 'Ve':
          jour_semaine = 4

        date_event = datetime.strptime(semaine, '%d/%m/%Y') + pd.DateOffset(days=jour_semaine)

        # Définir l'heure de début et de fin de l'événement
        heure_debut = int(heure_debut)
        heure_fin = int(heure_fin)

        # Créer un objet Événement
        event = Event()
        event.add('summary', f"Colle {matiere} {professeur}")
        event.add('location', salle)
        event.add('dtstart', datetime(date_event.year, date_event.month, date_event.day, heure_debut, 0))
        event.add('dtend', datetime(date_event.year, date_event.month, date_event.day, heure_fin, 0))
        cal.add_component(event)

# Enregistrer le calendrier dans un fichier .ics
with open(f"Colles/Colles de {matiere} groupe {round(group)}.ics", 'wb') as f:
    f.write(cal.to_ical())
# Out:
# Entrez le groupe de colle souhaité ici  12

# %% [markdown]
# # Maintenant, il faut récupérer les fichiers générés par le code python en allant dans l'onglet fichier juste à gauche

# %% [markdown]
# # Fichier de travail en dessous, ne pas executer

# %%
# Colles de Physique
import pandas as pd
from icalendar import Calendar, Event
from datetime import datetime
import io

data = '''
,horaire,salle,2/9/2024,9/9/2024,16/9/2024,23/9/2024,30/10/2024,7/10/2024,14/10/2024,,4/11/2024,11/11/2024,18/11/2024,25/11/2024,2/12/2024,9/12/2024,16/12/2024,,6/1/2025,13/1/2025,20/1/2025,27/1/2025,3/2/2025,10/2/2025,17/2/2025
,,,,,,,,,,,,,,,,,,,,,,,,,
Anglais,,,,,,,,,,,,,,,,,,,,,,,,,
Mme Tschudi,Lu 12-13,E02 E04,,,,1,2,3,4,,5,6,7,8,9,14,11,,12,13,14,1,2,3,2
Mme Mc Grath,Lu 12-13,E20,,,,3,4,13,6,,7,8,9,10,11,12,7,,14,7,16,15,6,1,4
Mme Mc Grath,Lu 13-14,E20,,,,5,12,1,14,,15,16,11,2,13,10,5,,8,1,2,3,4,5,6
Mme Rébillon,Lu 13-14,E08 E10,,,,7,8,9,8,,9,4,3,14,15,16,13,,2,15,4,5,16,11,8
M. Coquilhat,Lu 13-14,K08 K09,,,,9,10,5,12,,13,14,15,16,1,2,3,,16,11,6,7,8,9,10
Mme Heikka,Lu 18-19,E01 E05,,,,15,14,11,16,,11,10,1,12,3,4,15,,6,3,10,9,10,15,12
Mme Otéro,Ma 17-18,B21 B22,,,,13,6,15,10,,1,12,13,6,5,8,1,,4,9,8,13,12,7,14
Mme Otéro,Ma 18-19,B21 B22,,,,11,16,7,2,,3,2,5,4,7,6,9,,10,5,12,11,14,13,16
'''

group = float(input('Entrez le groupe de colle souhaité ici : '))

df = pd.read_csv(io.StringIO(data))

# Créer un objet Calendrier
cal = Calendar()

# Définir la matière
matiere = df.iloc[1,0]

# Parcourir les lignes du DataFrame à partir de la ligne 3 (index 2)
for index, ligne in df.iloc[2:].iterrows():
  # Extraire les informations
  professeur = ligne.iloc[0]
  info_date_heure = ligne.iloc[1]
  salle = ligne.iloc[2]

  # Parcourir les colonnes de dates à partir de la 4ème colonne (index 3)
  for i in range(3, len(df.columns)):
    semaine = df.columns[i]
    valeur = ligne.iloc[i]
    print(f"Checking value: {valeur}")  # LIGNE DE TEST DEBUG

    # Vérifier si la valeur est 14
    if valeur == 12:
      # Vérifier si la cellule contient le format attendu et n'est pas vide
      if isinstance(info_date_heure, str) and " " in info_date_heure:
        jour, horaire = info_date_heure.split(' ')
        heure_debut, heure_fin = horaire.split('-')

        # Calculer la date complète de l'événement
        if jour == 'Lu':
          jour_semaine = 0
        elif jour == 'Ma':
          jour_semaine = 1
        elif jour == 'Me':
          jour_semaine = 2
        elif jour == 'Je':
          jour_semaine = 3
        elif jour == 'Ve':
          jour_semaine = 4

        date_event = datetime.strptime(semaine, '%d/%m/%Y') + pd.DateOffset(days=jour_semaine)

        # Définir l'heure de début et de fin de l'événement
        heure_debut = int(heure_debut)
        heure_fin = int(heure_fin)

        # Créer un objet Événement
        event = Event()
        event.add('summary', f"Colle {matiere} {professeur}")
        event.add('location', salle)
        event.add('dtstart', datetime(date_event.year, date_event.month, date_event.day, heure_debut, 0))
        event.add('dtend', datetime(date_event.year, date_event.month, date_event.day, heure_fin, 0))
        cal.add_component(event)
        print(event) # LIGNE DE TEST DEBUG

print(cal)  # LIGNE DE TEST DEBUG

# Enregistrer le calendrier dans un fichier .ics
with open(f"Colles de {matiere} groupe {round(group)}.ics", 'wb') as f:
    f.write(cal.to_ical())
# Out:
# Entrez le groupe de colle souhaité ici :  14
# Checking value: nan
# Checking value: nan
# Checking value: nan
# Checking value: 1.0
# Checking value: 2.0
# Checking value: 3.0
# Checking value: 4.0
# Checking value: nan
# Checking value: 5.0
# Checking value: 6.0
# Checking value: 7.0
# Checking value: 8.0
# Checking value: 9.0
# Checking value: 14.0
# Checking value: 11.0
# Checking value: nan
# Checking value: 12.0
# VEVENT({'SUMMARY': vText(b'Colle Anglais Mme Tschudi'), 'LOCATION': vText(b'E02 E04'), 'DTSTART': vDDDTypes(2025-01-06 12:00:00, Parameters({})), 'DTEND': vDDDTypes(2025-01-06 13:00:00, Parameters({}))})
# Checking value: 13.0
# Checking value: 14.0
# Checking value: 1.0
# Checking value: 2.0
# Checking value: 3.0
# Checking value: 2.0
# Checking value: nan
# Checking value: nan
# Checking value: nan
# Checking value: 3.0
# Checking value: 4.0
# Checking value: 13.0
# Checking value: 6.0
# Checking value: nan
# Checking value: 7.0
# Checking value: 8.0
# Checking value: 9.0
# Checking value: 10.0
# Checking value: 11.0
# Checking value: 12.0
# VEVENT({'SUMMARY': vText(b'Colle Anglais Mme Mc Grath'), 'LOCATION': vText(b'E20'), 'DTSTART': vDDDTypes(2024-12-09 12:00:00, Parameters({})), 'DTEND': vDDDTypes(2024-12-09 13:00:00, Parameters({}))})
# Checking value: 7.0
# Checking value: nan
# Checking value: 14.0
# Checking value: 7.0
# Checking value: 16.0
# Checking value: 15.0
# Checking value: 6.0
# Checking value: 1.0
# Checking value: 4.0
# Checking value: nan
# Checking value: nan
# Checking value: nan
# Checking value: 5.0
# Checking value: 12.0
# VEVENT({'SUMMARY': vText(b'Colle Anglais Mme Mc Grath'), 'LOCATION': vText(b'E20'), 'DTSTART': vDDDTypes(2024-10-30 13:00:00, Parameters({})), 'DTEND': vDDDTypes(2024-10-30 14:00:00, Parameters({}))})
# Checking value: 1.0
# Checking value: 14.0
# Checking value: nan
# Checking value: 15.0
# Checking value: 16.0
# Checking value: 11.0
# Checking value: 2.0
# Checking value: 13.0
# Checking value: 10.0
# Checking value: 5.0
# Checking value: nan
# Checking value: 8.0
# Checking value: 1.0
# Checking value: 2.0
# Checking value: 3.0
# Checking value: 4.0
# Checking value: 5.0
# Checking value: 6.0
# Checking value: nan
# Checking value: nan
# Checking value: nan
# Checking value: 7.0
# Checking value: 8.0
# Checking value: 9.0
# Checking value: 8.0
# Checking value: nan
# Checking value: 9.0
# Checking value: 4.0
# Checking value: 3.0
# Checking value: 14.0
# Checking value: 15.0
# Checking value: 16.0
# Checking value: 13.0
# Checking value: nan
# Checking value: 2.0
# Checking value: 15.0
# Checking value: 4.0
# Checking value: 5.0
# Checking value: 16.0
# Checking value: 11.0
# Checking value: 8.0
# Checking value: nan
# Checking value: nan
# Checking value: nan
# Checking value: 9.0
# Checking value: 10.0
# Checking value: 5.0
# Checking value: 12.0
# VEVENT({'SUMMARY': vText(b'Colle Anglais M. Coquilhat'), 'LOCATION': vText(b'K08 K09'), 'DTSTART': vDDDTypes(2024-10-14 13:00:00, Parameters({})), 'DTEND': vDDDTypes(2024-10-14 14:00:00, Parameters({}))})
# Checking value: nan
# Checking value: 13.0
# Checking value: 14.0
# Checking value: 15.0
# Checking value: 16.0
# Checking value: 1.0
# Checking value: 2.0
# Checking value: 3.0
# Checking value: nan
# Checking value: 16.0
# Checking value: 11.0
# Checking value: 6.0
# Checking value: 7.0
# Checking value: 8.0
# Checking value: 9.0
# Checking value: 10.0
# Checking value: nan
# Checking value: nan
# Checking value: nan
# Checking value: 15.0
# Checking value: 14.0
# Checking value: 11.0
# Checking value: 16.0
# Checking value: nan
# Checking value: 11.0
# Checking value: 10.0
# Checking value: 1.0
# Checking value: 12.0
# VEVENT({'SUMMARY': vText(b'Colle Anglais Mme Heikka'), 'LOCATION': vText(b'E01 E05'), 'DTSTART': vDDDTypes(2024-11-25 18:00:00, Parameters({})), 'DTEND': vDDDTypes(2024-11-25 19:00:00, Parameters({}))})
# Checking value: 3.0
# Checking value: 4.0
# Checking value: 15.0
# Checking value: nan
# Checking value: 6.0
# Checking value: 3.0
# Checking value: 10.0
# Checking value: 9.0
# Checking value: 10.0
# Checking value: 15.0
# Checking value: 12.0
# VEVENT({'SUMMARY': vText(b'Colle Anglais Mme Heikka'), 'LOCATION': vText(b'E01 E05'), 'DTSTART': vDDDTypes(2025-02-17 18:00:00, Parameters({})), 'DTEND': vDDDTypes(2025-02-17 19:00:00, Parameters({}))})
# Checking value: nan
# Checking value: nan
# Checking value: nan
# Checking value: 13.0
# Checking value: 6.0
# Checking value: 15.0
# Checking value: 10.0
# Checking value: nan
# Checking value: 1.0
# Checking value: 12.0
# VEVENT({'SUMMARY': vText(b'Colle Anglais Mme Ot\xc3\xa9ro'), 'LOCATION': vText(b'B21 B22'), 'DTSTART': vDDDTypes(2024-11-12 17:00:00, Parameters({})), 'DTEND': vDDDTypes(2024-11-12 18:00:00, Parameters({}))})
# Checking value: 13.0
# Checking value: 6.0
# Checking value: 5.0
# Checking value: 8.0
# Checking value: 1.0
# Checking value: nan
# Checking value: 4.0
# Checking value: 9.0
# Checking value: 8.0
# Checking value: 13.0
# Checking value: 12.0
# VEVENT({'SUMMARY': vText(b'Colle Anglais Mme Ot\xc3\xa9ro'), 'LOCATION': vText(b'B21 B22'), 'DTSTART': vDDDTypes(2025-02-04 17:00:00, Parameters({})), 'DTEND': vDDDTypes(2025-02-04 18:00:00, Parameters({}))})
# Checking value: 7.0
# Checking value: 14.0
# Checking value: nan
# Checking value: nan
# Checking value: nan
# Checking value: 11.0
# Checking value: 16.0
# Checking value: 7.0
# Checking value: 2.0
# Checking value: nan
# Checking value: 3.0
# Checking value: 2.0
# Checking value: 5.0
# Checking value: 4.0
# Checking value: 7.0
# Checking value: 6.0
# Checking value: 9.0
# Checking value: nan
# Checking value: 10.0
# Checking value: 5.0
# Checking value: 12.0
# VEVENT({'SUMMARY': vText(b'Colle Anglais Mme Ot\xc3\xa9ro'), 'LOCATION': vText(b'B21 B22'), 'DTSTART': vDDDTypes(2025-01-21 18:00:00, Parameters({})), 'DTEND': vDDDTypes(2025-01-21 19:00:00, Parameters({}))})
# Checking value: 11.0
# Checking value: 14.0
# Checking value: 13.0
# Checking value: 16.0
# VCALENDAR({}, VEVENT({'SUMMARY': vText(b'Colle Anglais Mme Tschudi'), 'LOCATION': vText(b'E02 E04'), 'DTSTART': vDDDTypes(2025-01-06 12:00:00, Parameters({})), 'DTEND': vDDDTypes(2025-01-06 13:00:00, Parameters({}))}), VEVENT({'SUMMARY': vText(b'Colle Anglais Mme Mc Grath'), 'LOCATION': vText(b'E20'), 'DTSTART': vDDDTypes(2024-12-09 12:00:00, Parameters({})), 'DTEND': vDDDTypes(2024-12-09 13:00:00, Parameters({}))}), VEVENT({'SUMMARY': vText(b'Colle Anglais Mme Mc Grath'), 'LOCATION': vText(b'E20'), 'DTSTART': vDDDTypes(2024-10-30 13:00:00, Parameters({})), 'DTEND': vDDDTypes(2024-10-30 14:00:00, Parameters({}))}), VEVENT({'SUMMARY': vText(b'Colle Anglais M. Coquilhat'), 'LOCATION': vText(b'K08 K09'), 'DTSTART': vDDDTypes(2024-10-14 13:00:00, Parameters({})), 'DTEND': vDDDTypes(2024-10-14 14:00:00, Parameters({}))}), VEVENT({'SUMMARY': vText(b'Colle Anglais Mme Heikka'), 'LOCATION': vText(b'E01 E05'), 'DTSTART': vDDDTypes(2024-11-25 18:00:00, Parameters({})), 'DTEND': vDDDTypes(2024-11-25 19:00:00, Parameters({}))}), VEVENT({'SUMMARY': vText(b'Colle Anglais Mme Heikka'), 'LOCATION': vText(b'E01 E05'), 'DTSTART': vDDDTypes(2025-02-17 18:00:00, Parameters({})), 'DTEND': vDDDTypes(2025-02-17 19:00:00, Parameters({}))}), VEVENT({'SUMMARY': vText(b'Colle Anglais Mme Ot\xc3\xa9ro'), 'LOCATION': vText(b'B21 B22'), 'DTSTART': vDDDTypes(2024-11-12 17:00:00, Parameters({})), 'DTEND': vDDDTypes(2024-11-12 18:00:00, Parameters({}))}), VEVENT({'SUMMARY': vText(b'Colle Anglais Mme Ot\xc3\xa9ro'), 'LOCATION': vText(b'B21 B22'), 'DTSTART': vDDDTypes(2025-02-04 17:00:00, Parameters({})), 'DTEND': vDDDTypes(2025-02-04 18:00:00, Parameters({}))}), VEVENT({'SUMMARY': vText(b'Colle Anglais Mme Ot\xc3\xa9ro'), 'LOCATION': vText(b'B21 B22'), 'DTSTART': vDDDTypes(2025-01-21 18:00:00, Parameters({})), 'DTEND': vDDDTypes(2025-01-21 19:00:00, Parameters({}))}))

# %% [markdown]
# # Test 3/12/2024 utiliser seulement une fonction avec le jeu de data en argument

# %% [markdown]
# CONCLUSION : CA MARCHE AVEC DES FONCTIONS MAIS YA UN PROBLEME DE JOURS MTN... A POURSUIVRE

# %%
# Test 3/12/2024 utiliser seulement une fonction avec le jeu de data en argument 
import pandas as pd
from icalendar import Calendar, Event
from datetime import datetime
import io

def pdc(data):
    """
    In : data sous forme de jeux de données (Total = 4)
    Out : Fichier Ical format ics éditable en txt
    """
    
    df = pd.read_csv(io.StringIO(data))
    
    # Créer un objet Calendrier
    cal = Calendar()
    
    # Définir la matière
    matiere = df.iloc[1,0].strip()
    
    # Parcourir les lignes du DataFrame à partir de la ligne 3 (index 2)
    for index, ligne in df.iloc[2:].iterrows():
      # Extraire les informations
      professeur = ligne.iloc[0].strip()
      info_date_heure = ligne.iloc[1]
      salle = ligne.iloc[2]
    
      # Parcourir les colonnes de dates à partir de la 4ème colonne (index 3)
      for i in range(3, len(df.columns)):
        semaine = df.columns[i]
        valeur = ligne.iloc[i]
    
        # Vérifier si la valeur est celle demandée
        if valeur == group:
          # Vérifier si la cellule contient le format attendu et n'est pas vide
          if isinstance(info_date_heure, str) and " " in info_date_heure:
            jour, horaire = info_date_heure.split(' ')
            heure_debut, heure_fin = horaire.split('-')
    
            # Calculer la date complète de l'événement
            # Calculer le jour relatif
            if jour == 'Lu':
              jour_semaine = 0
            elif jour == 'Ma':
              jour_semaine = 1
            elif jour == 'Me':
              jour_semaine = 2
            elif jour == 'Je':
              jour_semaine = 3
            elif jour == 'Ve':
              jour_semaine = 4
            # Calculer la date complete
            date_event = datetime.strptime(semaine, '%d/%m/%Y') + pd.DateOffset(days=jour_semaine)
    
            # Définir l'heure de début et de fin de l'événement
            heure_debut = int(heure_debut)
            heure_fin = int(heure_fin)
    
            # Créer un objet Événement
            event = Event()
            event.add('summary', f"Colle {matiere} {professeur}")
            event.add('location', salle)
            event.add('dtstart', datetime(date_event.year, date_event.month, date_event.day, heure_debut, 0))
            event.add('dtend', datetime(date_event.year, date_event.month, date_event.day, heure_fin, 0))
            cal.add_component(event)

    return (cal.to_ical())

def savefile(nomfichier):
    """
    In : filename
    Out : Ics file
    """
    assert type(nomfichier) == str
    jeu1 = pdc('''
    ,horaire,salle,2/9/2024,9/9/2024,16/9/2024,23/9/2024,30/9/2024,7/10/2024,14/10/2024,,4/11/2024,11/11/2024,18/11/2024,25/11/2024,2/12/2024,9/12/2024,16/12/2024,,6/1/2025,13/1/2025,20/1/2025,27/1/2025,3/2/2025,10/2/2025,17/2/2025
    ,,,,,,,,,,,,,,,,,,,,,,,,,
    Anglais,,,,,,,,,,,,,,,,,,,,,,,,,
    Mme Tschudi,Lu 12-13,E02 E04,,,,1,2,3,4,,5,6,7,8,9,14,11,,12,13,14,1,2,3,2
    Mme Mc Grath,Lu 12-13,E20,,,,3,4,13,6,,7,8,9,10,11,12,7,,14,7,16,15,6,1,4
    Mme Mc Grath,Lu 13-14,E20,,,,5,12,1,14,,15,16,11,2,13,10,5,,8,1,2,3,4,5,6
    Mme Rébillon,Lu 13-14,E08 E10,,,,7,8,9,8,,9,4,3,14,15,16,13,,2,15,4,5,16,11,8
    M. Coquilhat,Lu 13-14,K08 K09,,,,9,10,5,12,,13,14,15,16,1,2,3,,16,11,6,7,8,9,10
    Mme Heikka,Lu 18-19,E01 E05,,,,15,14,11,16,,11,10,1,12,3,4,15,,6,3,10,9,10,15,12
    Mme Otéro,Ma 17-18,B21 B22,,,,13,6,15,10,,1,12,13,6,5,8,1,,4,9,8,13,12,7,14
    Mme Otéro,Ma 18-19,B21 B22,,,,11,16,7,2,,3,2,5,4,7,6,9,,10,5,12,11,14,13,16
    ''')
    jeu2 = pdc('''
    ,horaire,salle,2/9/2024,9/9/2024,16/9/2024,23/9/2024,30/9/2024,7/10/2024,14/10/2024,,4/11/2024,11/11/2024,18/11/2024,25/11/2024,2/12/2024,9/12/2024,16/12/2024,,6/1/2025,13/1/2025,20/1/2025,27/1/2025,3/2/2025,10/2/2025,17/2/2025
    ,,,,,,,,,,,,,,,,,,,,,,,,,
    Maths,,,,,,,,,,,,,,,,,,,,,,,,,
    M. Sautonie,Lu 12-13,E01,,,,,16,7,2,,11,10,5,6,7,4,9,,10,3,12,9,14,15,16
    M. Falconnet,Lu 13-14,F106,,,,,14,11,16,,1,2,1,12,5,6,15,,6,5,10,11,12,13,14
    Mme Plà,Ma 12-13,E01,,,,,8,1,14,,9,16,7,2,3,12,5,,14,7,8,13,4,3,12
    Mme Plà,Ma 13-14,E01,,,,,10,15,12,,5,14,15,10,1,8,3,,4,9,6,1,8,9,10
    M. Magniez,Ma 13-14,F103,,,,,6,5,10,,3,12,13,8,15,16,1,,2,11,4,5,16,1,2
    M. Sageaux,Ma 17-18,F205,,,,,4,13,8,,7,4,11,4,13,10,7,,16,13,2,15,10,5,4
    M. Raymond,Ma 18-19,E04,,,,,12,9,6,,15,8,9,16,11,14,13,,12,15,16,7,2,11,6
    Mme Deville,Je 17-18,B21,,,,,2,3,4,,13,6,3,14,9,2,11,,8,1,14,3,6,7,8
    ''')
    jeu3 = pdc('''
    ,horaire,salle,2/9/2024,9/9/2024,16/9/2024,23/9/2024,30/9/2024,7/10/2024,14/10/2024,,4/11/2024,11/11/2024,18/11/2024,25/11/2024,2/12/2024,9/12/2024,16/12/2024,,6/1/2025,13/1/2025,20/1/2025,27/1/2025,3/2/2025,10/2/2025,17/2/2025
    ,,,,,,,,,,,,,,,,,,,,,,,,,
    SI,,,,,,,,,,,,,,,,,,,,,,,,,
    Mme Pradier,Lu 12-13,B21,,,,2,11,4,3,,2,5,8,1,10,9,12,,11,8,13,16,15,2,11
    M. Lisle,Lu 12-13,Labo PT,,,,4,3,6,5,,8,7,10,15,8,11,6,,13,16,15,8,1,4,3
    Mme Pradier,Lu 13-14,B21,,,,6,5,2,7,,14,9,12,11,4,13,16,,15,2,1,12,3,6,5
    M. Boyer,Lu 13-14,Labo PT,,,,8,7,10,9,,12,11,4,13,16,7,2,,1,6,9,6,5,8,7
    M. Lisle,Ma 12-13,Labo PT,,,,16,9,12,11,,10,3,16,9,2,15,10,,3,14,5,4,7,10,15
    M. Deluche,Ma 18-19,Labo PT,,,,12,15,14,13,,16,15,6,7,14,3,14,,5,4,7,2,13,16,1
    M. Vallenet,Je 17-18,Labo PT,,,,14,13,16,15,,6,1,14,3,6,5,8,,7,12,11,14,11,14,13
    M. Deluche,Ve 13-14,Labo PT,,,,10,1,8,1,,4,13,2,5,12,1,4,,9,10,3,10,9,12,9
    ''')
    jeu4 = pdc('''
    ,horaire,salle,2/9/2024,9/9/2024,16/9/2024,23/9/2024,30/9/2024,7/10/2024,14/10/2024,,4/11/2024,11/11/2024,18/11/2024,25/11/2024,2/12/2024,9/12/2024,16/12/2024,,6/1/2025,13/1/2025,20/1/2025,27/1/2025,3/2/2025,10/2/2025,17/2/2025
    ,,,,,,,,,,,,,,,,,,,,,,,,,
    Physique,,,,,,,,,,,,,,,,,,,,,,,,,
    Mme Lefort,Lu 12-13,H105,,,,,15,8,1,,10,3,16,9,2,1,10,,9,4,11,14,13,16,15
    M. Raimi,Lu 12-13,H108,,,,,13,16,15,,6,1,14,3,6,5,8,,7,10,3,2,11,14,13
    M. Qadri,Lu 12-13,B23,,,,,9,14,13,,16,15,2,7,14,15,14,,3,14,7,10,9,12,1
    M. Scotto,Ma 17-18,H111,,,,,1,6,11,,4,13,10,5,12,7,4,,5,12,5,16,7,6,5
    Mme Lines,Me 17-18,H105,,,,,11,4,9,,8,11,4,15,4,11,6,,15,6,9,4,15,8,9
    M. Trollet,Me 18-19,H105,,,,,7,2,7,,14,5,12,11,16,13,16,,1,16,15,6,5,10,3
    M Fayolle,Ve 12-13,E102,,,,,3,12,5,,12,7,6,13,8,3,2,,13,2,1,8,1,4,7
    M Fanjeaux,Ve 12-13,H113,,,,,5,10,3,,2,9,8,1,10,9,12,,11,8,13,12,3,2,11
    ''')
    # Enregistrer le calendrier complet dans un fichier .ics (opération de sommation)
    with open(nomfichier, 'ab') as f:
        f.write(jeu1)
        f.write(jeu2)
        f.write(jeu3)
        f.write(jeu4)
    cleaner(nomfichier)

def cleaner(nomfichier):
    """
    In : Fichier Ical Global après sommation
    Out : Fichier Ical fonctionnel et prêt
    """
    # Read the file and filter lines
    with open(nomfichier, 'r') as f:
        lines = f.readlines()
    
    # Remove unwanted lines
    filtered_lines = [line for line in lines if line.strip() not in ("BEGIN:VCALENDAR", "END:VCALENDAR")]
    
    # Add BEGIN:VCALENDAR and END:VCALENDAR
    filtered_lines.insert(0, "BEGIN:VCALENDAR\n")  # Add to the beginning
    filtered_lines.append("END:VCALENDAR\n")     # Add to the end
    
    # Write the modified lines back to the file
    with open(nomfichier, 'w') as f:
        f.writelines(filtered_lines)

def export():
    """
    In : none
    Out : none, envoi les fichiers vers le bon répertoire, et séparément
    """
    global group
    group = 1
    for i in range(1,17):
        group = i
        savefile(f"../Documents/Cours lycée/Archive/Première 2022:2023/NSI/jeanprt.github.io/colles/Colles groupe {round(group)}.ics")
    print("success")
"""
def run(groupe):
    global group
    group = groupe
    savefile(f"Colles/Colles groupe {round(group)}.ics")
    print("success")
run(14)
"""
export()
# Out:
# success

# %%
# Run 15/01/2025 nvo programme
import pandas as pd
from icalendar import Calendar, Event
from datetime import datetime
import io

def pdc(data):
    """
    In : data sous forme de jeux de données (Total = 4)
    Out : Fichier Ical format ics éditable en txt
    """
    
    df = pd.read_csv(io.StringIO(data))
    
    # Créer un objet Calendrier
    cal = Calendar()
    
    # Définir la matière
    matiere = df.iloc[1,0].strip()
    
    # Parcourir les lignes du DataFrame à partir de la ligne 3 (index 2)
    for index, ligne in df.iloc[2:].iterrows():
      # Extraire les informations
      professeur = ligne.iloc[0].strip()
      info_date_heure = ligne.iloc[1]
      salle = ligne.iloc[2]
    
      # Parcourir les colonnes de dates à partir de la 4ème colonne (index 3)
      for i in range(3, len(df.columns)):
        semaine = df.columns[i]
        valeur = ligne.iloc[i]
    
        # Vérifier si la valeur est celle demandée
        if valeur == group:
          # Vérifier si la cellule contient le format attendu et n'est pas vide
          if isinstance(info_date_heure, str) and " " in info_date_heure:
            jour, horaire = info_date_heure.split(' ')
            heure_debut, heure_fin = horaire.split('-')
    
            # Calculer la date complète de l'événement
            # Calculer le jour relatif
            if jour == 'Lu':
              jour_semaine = 0
            elif jour == 'Ma':
              jour_semaine = 1
            elif jour == 'Me':
              jour_semaine = 2
            elif jour == 'Je':
              jour_semaine = 3
            elif jour == 'Ve':
              jour_semaine = 4
            # Calculer la date complete
            date_event = datetime.strptime(semaine, '%d/%m/%Y') + pd.DateOffset(days=jour_semaine)
    
            # Définir l'heure de début et de fin de l'événement
            heure_debut = int(heure_debut)
            heure_fin = int(heure_fin)
    
            # Créer un objet Événement
            event = Event()
            event.add('summary', f"Colle {matiere} {professeur}")
            event.add('location', salle)
            event.add('dtstart', datetime(date_event.year, date_event.month, date_event.day, heure_debut, 0, 0, tzinfo=None))
            event.add('dtend', datetime(date_event.year, date_event.month, date_event.day, heure_fin, 0, 0, tzinfo=None))
            event.add('description', Version)  # Ajout en description
            event['dtstart'].params['TZID'] = "Europe/Paris"
            event['dtend'].params['TZID'] = "Europe/Paris"
            event
            cal.add_component(event)

    return (cal.to_ical())

def savefile(nomfichier):
    """
    In : filename
    Out : Ics file
    """
    assert type(nomfichier) == str
    jeu1 = pdc('''
    ,horaire,salle,2/9/2024,9/9/2024,16/9/2024,23/9/2024,30/9/2024,7/10/2024,14/10/2024,,4/11/2024,11/11/2024,18/11/2024,25/11/2024,2/12/2024,9/12/2024,16/12/2024,,6/1/2025,13/1/2025,20/1/2025,27/1/2025,3/2/2025,10/2/2025,17/2/2025,,10/3/2025,17/3/2025,24/3/2025,31/3/2025,7/4/2025,14/4/2025,,5/5/2025,12/5/2025,19/5/2025,26/5/2025,2/6/2025,9/6/2025,16/6/2025,23/6/2025
    ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
    Anglais,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
    Mme Tschudi,Lu 12-13,E02 E04,,,,1,2,3,4,,5,6,7,8,9,14,11,,12,13,14,1,2,3,2,,1,2,3,4,5,6,,7,,9,14,11,12
    Mme Mc Grath,Lu 12-13,E20,,,,3,4,13,6,,7,8,9,10,11,12,7,,14,7,16,15,6,1,4,,3,4,13,6,7,,,9,10,11,12,7,14
    Mme Mc Grath,Lu 13-14,E20,,,,5,12,1,14,,15,16,11,2,13,10,5,,,1,2,3,4,5,6,,15,,1,14,15,16,,11,2,13,10,5,
    Mme Rébillon,Lu 13-14,E08 E10,,,,7,8,9,8,,9,4,3,14,15,16,13,,2,15,4,5,16,11,,,7,12,9,,9,4,,3,14,15,16,13,2
    M. Coquilhat,Lu 13-14,K08 K09,,,,9,10,5,12,,13,14,15,16,1,2,3,,16,11,6,7,,9,10,,9,10,5,12,13,14,,15,16,1,2,3,16
    Mme Heikka,Lu 18-19,E01 E05,,,,15,14,11,16,,11,10,1,12,3,4,15,,6,3,10,9,10,15,12,,5,14,11,16,11,10,,1,12,3,4,15,6
    Mme Otéro,Ma 17-18,B21 B22,,,,13,6,15,10,,1,12,13,6,5,8,1,,4,9,,13,12,7,14,,11,6,15,10,1,12,,13,6,5,,1,4
    Mme Otéro,Ma 18-19,B21 B22,,,,11,16,7,2,,3,2,5,4,7,6,9,,10,5,12,11,14,13,16,,13,16,7,2,3,2,,5,4,7,6,9,10
    ''')
    jeu2 = pdc('''
    ,horaire,salle,2/9/2024,9/9/2024,16/9/2024,23/9/2024,30/9/2024,7/10/2024,14/10/2024,,4/11/2024,11/11/2024,18/11/2024,25/11/2024,2/12/2024,9/12/2024,16/12/2024,,6/1/2025,13/1/2025,20/1/2025,27/1/2025,3/2/2025,10/2/2025,17/2/2025,,10/3/2025,17/3/2025,24/3/2025,31/3/2025,7/4/2025,14/4/2025,,5/5/2025,12/5/2025,19/5/2025,26/5/2025,2/6/2025,9/6/2025,16/6/2025,23/6/2025
    ,,,,,,,,,,,,,,,,,,,,,,,,,
    Maths,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
    M. Sautonie,Lu 12-13,E01,,,,15,16,7,2,,11,10,5,6,7,4,9,,10,3,12,9,14,15,16,,11,16,7,2,11,10,,5,6,7,4,9,
    M. Falconnet,Lu 13-14,F106,,,,5,14,11,16,,1,2,1,12,5,6,15,,6,5,10,11,12,13,14,,5,14,11,16,1,2,,1,12,5,6,15,
    Mme Plà,Ma 12-13,E01,,,,11,8,1,14,,9,16,7,2,3,12,5,,14,7,,13,4,3,12,,15,,1,14,9,16,,7,2,3,12,5,
    Mme Plà,Ma 13-14,E01,,,,9,10,15,12,,5,14,15,10,1,8,3,,4,9,6,1,,9,10,,9,10,15,12,5,14,,15,10,1,,3,
    M. Magniez,Ma 13-14,F103,,,,7,6,5,10,,3,12,13,8,15,16,1,,2,11,4,5,16,1,2,,7,6,5,10,3,12,,13,,15,16,1,
    M. Sageaux,Ma 17-18,F205,,,,13,4,13,8,,7,4,11,4,13,10,7,,16,13,2,15,10,5,4,,13,4,13,,7,4,,11,4,13,10,7,
    M. Raymond,Ma 18-19,E04,,,,3,12,9,6,,15,8,9,16,11,14,13,,12,15,16,7,2,11,6,,3,12,9,6,15,,,9,16,11,14,13,
    Mme Deville,Je 17-18,B21,,,,1,2,3,4,,13,6,3,14,9,2,11,,,1,14,3,6,7,,,1,2,3,4,13,6,,3,14,9,2,11,
    ''')
    jeu3 = pdc('''
    ,horaire,salle,2/9/2024,9/9/2024,16/9/2024,23/9/2024,30/9/2024,7/10/2024,14/10/2024,,4/11/2024,11/11/2024,18/11/2024,25/11/2024,2/12/2024,9/12/2024,16/12/2024,,6/1/2025,13/1/2025,20/1/2025,27/1/2025,3/2/2025,10/2/2025,17/2/2025,,10/3/2025,17/3/2025,24/3/2025,31/3/2025,7/4/2025,14/4/2025,,5/5/2025,12/5/2025,19/5/2025,26/5/2025,2/6/2025,9/6/2025,16/6/2025,23/6/2025
    ,,,,,,,,,,,,,,,,,,,,,,,,,
    SI,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
    Mme Pradier,Lu 12-13,B21,,,,2,11,4,3,,2,5,8,1,10,9,12,,11,,13,16,15,2,11,,2,3,4,3,2,5,,6,1,10,9,12,11
    M. Lisle,Lu 12-13,Labo PT,,,,4,3,6,5,,8,7,10,15,8,11,6,,13,16,15,,1,4,3,,4,11,6,5,12,7,,10,15,,11,6,13
    Mme Pradier,Lu 13-14,B21,,,,6,5,2,7,,14,9,12,11,4,13,16,,15,2,1,12,3,6,5,,,7,2,7,14,9,,12,11,4,13,16,15
    M. Boyer,Lu 13-14,Labo PT,,,,8,7,10,9,,12,11,4,13,16,7,2,,1,6,9,6,5,,7,,6,5,10,9,,11,,4,13,16,7,2,1
    M. Lisle,Ma 12-13,Labo PT,,,,16,9,12,11,,10,3,16,9,2,15,10,,3,14,5,4,7,10,15,,16,9,12,11,10,3,,16,9,2,15,10,3
    M. Deluche,Ma 18-19,Labo PT,,,,12,15,14,13,,16,15,6,7,14,3,14,,5,4,7,2,13,16,1,,12,15,14,13,16,15,,,7,14,3,14,5
    M. Vallenet,Je 17-18,Labo PT,,,,14,13,16,15,,6,1,14,3,6,5,8,,7,12,11,14,11,14,13,,14,13,16,15,6,1,,14,3,6,5,,7
    M. Deluche,Ve 13-14,Labo PT,,,,10,1,8,1,,4,13,2,5,12,1,4,,9,10,3,10,9,12,9,,10,1,,1,4,13,,2,5,12,1,4,9
    ''')
    jeu4 = pdc('''
    ,horaire,salle,2/9/2024,9/9/2024,16/9/2024,23/9/2024,30/9/2024,7/10/2024,14/10/2024,,4/11/2024,11/11/2024,18/11/2024,25/11/2024,2/12/2024,9/12/2024,16/12/2024,,6/1/2025,13/1/2025,20/1/2025,27/1/2025,3/2/2025,10/2/2025,17/2/2025,,10/3/2025,17/3/2025,24/3/2025,31/3/2025,7/4/2025,14/4/2025,,5/5/2025,12/5/2025,19/5/2025,26/5/2025,2/6/2025,9/6/2025,16/6/2025,23/6/2025
    ,,,,,,,,,,,,,,,,,,,,,,,,,
    Physique,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
    Mme Lefort,Lu 12-13,H105,,,,16,15,8,1,,10,3,16,9,2,1,10,,9,4,11,14,13,16,1,,14,15,,1,16,3,,14,9,2,1,10,9
    M. Raimi,Lu 12-13,H108,,,,14,13,16,15,,6,1,14,3,6,5,8,,7,10,3,2,11,14,15,,12,13,16,15,6,1,,16,3,14,5,,7
    M. Qadri,Lu 12-13,B23,,,,12,9,14,13,,16,15,2,7,14,15,14,,3,14,7,10,9,12,13,,16,9,14,13,10,15,,2,7,6,15,14,3
    M. Scotto,Ma 17-18,H111,,,,10,1,6,11,,4,13,10,5,12,7,4,,5,12,5,16,7,6,5,,10,1,4,11,4,13,,10,5,12,7,4,5
    Mme Lines,Me 17-18,H105,,,,8,11,4,9,,8,11,4,15,4,11,6,,15,6,9,4,15,,9,,6,11,6,9,,11,,4,15,4,11,6,15
    M. Trollet,Me 18-19,H105,,,,6,7,2,7,,14,5,12,11,16,13,16,,1,16,15,6,5,10,3,,,7,2,5,14,5,,12,11,16,13,16,1
    M Fayolle,Ve 12-13,E102,,,,4,3,12,5,,12,7,6,13,8,3,2,,13,2,1,,1,4,7,,2,3,12,7,12,7,,6,13,,3,2,13
    ''')
    # Enregistrer le calendrier complet dans un fichier .ics (opération de sommation)
    with open(nomfichier, 'ab') as f:
        f.write(jeu1)
        f.write(jeu2)
        f.write(jeu3)
        f.write(jeu4)
    cleaner(nomfichier)

def cleaner(nomfichier):
    """
    In : Fichier Ical Global après sommation
    Out : Fichier Ical fonctionnel et prêt
    """
    # Read the file and filter lines
    with open(nomfichier, 'r') as f:
        lines = f.readlines()
    
    # Remove unwanted lines
    filtered_lines = [line for line in lines if line.strip() not in ("BEGIN:VCALENDAR", "END:VCALENDAR")]
    
    # Ajout d'infos début et fin de calendrier et de fuseau horaire
    # Ajout d'une indication de fuseau horaire
    filtered_lines.insert(0,"""VERSION:2.0
CALSCALE:GREGORIAN
BEGIN:VTIMEZONE
TZID:Europe/Paris
X-LIC-LOCATION:Europe/Paris
BEGIN:DAYLIGHT
TZOFFSETFROM:+0100
TZOFFSETTO:+0200
TZNAME:CEST
DTSTART:19700329T020000
RRULE:FREQ=YEARLY;BYMONTH=3;BYDAY=-1SU
END:DAYLIGHT
BEGIN:STANDARD
TZOFFSETFROM:+0200
TZOFFSETTO:+0100
TZNAME:CET
DTSTART:19701025T030000
RRULE:FREQ=YEARLY;BYMONTH=10;BYDAY=-1SU
END:STANDARD
END:VTIMEZONE\n\n""")
    
    filtered_lines.insert(0, "BEGIN:VCALENDAR\n")  # Ajout au debut
    
    filtered_lines.append("END:VCALENDAR\n")     # Ajout à la fin
    
    
    # Write the modified lines back to the file
    with open(nomfichier, 'w') as f:
        f.writelines(filtered_lines)

def export():
    """
    In : none
    Out : none, envoi les fichiers vers le bon répertoire, et séparément
    """
    print('Starting computation...')
    global Version
    Version = "V16"
    global group
    group = 1
    for i in range(1,17):
        group = i
        savefile(f"../Documents/Cours lycée/Archive/Première 2022:2023/NSI/jeanprt.github.io/colles/Colles groupe {round(group)}.ics")
        print(f'Fetching group {round(group)}...')
    print("Success !")
"""
def run(groupe):
    global group
    group = groupe
    savefile(f"Colles/Colles groupe {round(group)}.ics")
    print("Success !")
run(14)
"""
export()
# Out:
# Starting computation...
# Fetching group 1...
# Fetching group 2...
# Fetching group 3...
# Fetching group 4...
# Fetching group 5...
# Fetching group 6...
# Fetching group 7...
# Fetching group 8...
# Fetching group 9...
# Fetching group 10...
# Fetching group 11...
# Fetching group 12...
# Fetching group 13...
# Fetching group 14...
# Fetching group 15...
# Fetching group 16...
# Success !
